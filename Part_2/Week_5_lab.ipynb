# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd

# %%
# Read the CSV file
data = pd.read_csv("YelloTaxiData.csv")

# %%
# Visualising the data
data.head()
# Out:
#    RateCodeID  RatecodeID  VendorID  dropoff_latitude  dropoff_longitude  \
# 0         1.0         NaN         1         40.782337         -73.972160
# 1         1.0         NaN         1         40.720489         -73.945465
# 2         1.0         NaN         1         40.721367         -73.994781
# 3         1.0         NaN         1          0.000000           0.000000
# 4         1.0         NaN         2         40.737110         -73.998177
#
#    extra  fare_amount  improvement_surcharge  mta_tax  passenger_count  \
# 0    0.0          5.0                    0.3      0.5                1
# 1    0.5         12.5                    0.3      0.5                1
# 2    0.0         14.5                    0.3      0.5                2
# 3    1.0          4.0                    0.3      0.5                1
# 4    0.0          4.5                    0.3      0.5                1
#
#    payment_type  pickup_latitude  pickup_longitude store_and_fwd_flag  \
# ...

# %%
# Deleting from the 101st row till the last row
data = data.drop(data.index[100:])

# %%
data.tail()
# Out:
#     RateCodeID  RatecodeID  VendorID  dropoff_latitude  dropoff_longitude  \
# 95         1.0         NaN         2         40.753021         -73.985489
# 96         1.0         NaN         1         40.738331         -73.984406
# 97         1.0         NaN         1         40.714813         -73.991684
# 98         1.0         NaN         2         40.755112         -73.972198
# 99         1.0         NaN         1         40.800392         -73.955452
#
#     extra  fare_amount  improvement_surcharge  mta_tax  passenger_count  \
# 95    0.0         12.5                    0.3      0.5                1
# 96    0.0          9.0                    0.0      0.5                2
# 97    0.5          9.0                    0.3      0.5                1
# 98    1.0          6.0                    0.3      0.5                5
# 99    0.0         21.5                    0.0      0.5                1
#
#     payment_type  pickup_latitude  pickup_longitude store_and_fwd_flag  \
# ...

# %%
# Saving dataframe to a new csv file
data.to_csv("YelloTaxiData_new.csv", index=False)
